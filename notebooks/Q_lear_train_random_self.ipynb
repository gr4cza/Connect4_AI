# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from connect4.agent.q_learn import QLearnTrain
from connect4.agent.random_agent import RandomAgent
from connect4.agent.min_max import MinMaxAgentWAlphaBeta
from connect4.agent.monte_carlo import MonteCarlo
from connect4.evaluator import AdvancedScore

from matplotlib import pyplot as plt
from time import time

# %%
def plot_train_data(rounds, t, name, half):
    x = [x for x in range(0, rounds, int(rounds/t.resolution))]
    if half==1:
        win = [x[0] for x in t.win_loose[:t.resolution]]
        loose = [x[1] for x in t.win_loose[:t.resolution]]
        draw = [x[2] for x in t.win_loose[:t.resolution]]
        dist = [x[1]-x[0] for x in t.win_loose[:t.resolution]]
    else:
        win = [x[1] for x in t.win_loose[t.resolution:]]
        loose = [x[0] for x in t.win_loose[t.resolution:]]
        draw = [x[2] for x in t.win_loose[t.resolution:]]
        dist = [x[0]-x[1] for x in t.win_loose[t.resolution:]]
        
    plt.plot(x, win, label='win')
    plt.plot(x, loose, label='loose')
    plt.plot(x, draw, label='draw')
    plt.plot(x, dist, label='distance')
    
    plt.xlabel('Round')
    plt.ylabel('Piece')
    plt.title(f'{name}_{rounds}_p{half}')
    
    plt.legend()
    plt.grid()
    
    plt.show()

# %%
def train(against=None, rounds=10_000, name=''):
    t = QLearnTrain()
       
    start_time = time()
    t.learn(rounds, against=against, name=name)
    print(f'time: {time() - start_time}s')
    
    plot_train_data(rounds,t,name,1)
    if against is not None:
        plot_train_data(rounds,t,name,2)

# %%
train(RandomAgent,name='RandomAgent')
# Out:
# iteration: 0.
# iteration: 500.
# iteration: 1000.
# iteration: 1500.
# iteration: 2000.
# iteration: 2500.
# iteration: 3000.
# iteration: 3500.
# iteration: 4000.
# iteration: 4500.
# iteration: 5000.
# iteration: 5500.
# iteration: 6000.
# iteration: 6500.
# iteration: 7000.
# iteration: 7500.
# iteration: 8000.
# iteration: 8500.
# iteration: 9000.
# iteration: 9500.
# p1: 6696, p2: 3285, d: 19
# iteration: 0.
# iteration: 500.
# iteration: 1000.
# iteration: 1500.
# iteration: 2000.
# iteration: 2500.
# iteration: 3000.
# iteration: 3500.
# iteration: 4000.
# iteration: 4500.
# iteration: 5000.
# iteration: 5500.
# iteration: 6000.
# iteration: 6500.
# iteration: 7000.
# iteration: 7500.
# iteration: 8000.
# iteration: 8500.
# iteration: 9000.
# iteration: 9500.
# p1: 4903, p2: 5070, d: 27
# save model as: RandomAgent_20191211_230651
# time: 45.07400178909302s

# %%
train(RandomAgent,rounds=20_000,name='RandomAgent')
# Out:
# iteration: 0.
# iteration: 1000.
# iteration: 2000.
# iteration: 3000.
# iteration: 4000.
# iteration: 5000.
# iteration: 6000.
# iteration: 7000.
# iteration: 8000.
# iteration: 9000.
# iteration: 10000.
# iteration: 11000.
# iteration: 12000.
# iteration: 13000.
# iteration: 14000.
# iteration: 15000.
# iteration: 16000.
# iteration: 17000.
# iteration: 18000.
# iteration: 19000.
# p1: 13864, p2: 6083, d: 53
# iteration: 0.
# iteration: 1000.
# iteration: 2000.
# iteration: 3000.
# iteration: 4000.
# iteration: 5000.
# iteration: 6000.
# iteration: 7000.
# iteration: 8000.
# iteration: 9000.
# iteration: 10000.
# iteration: 11000.
# iteration: 12000.
# iteration: 13000.
# iteration: 14000.
# iteration: 15000.
# iteration: 16000.
# iteration: 17000.
# iteration: 18000.
# iteration: 19000.
# p1: 9480, p2: 10467, d: 53
# save model as: RandomAgent_20191211_211252
# time: 83.51896548271179s

# %%
train(name='self')
# Out:
# iteration: 0.
# iteration: 500.
# iteration: 1000.
# iteration: 1500.
# iteration: 2000.
# iteration: 2500.
# iteration: 3000.
# iteration: 3500.
# iteration: 4000.
# iteration: 4500.
# iteration: 5000.
# iteration: 5500.
# iteration: 6000.
# iteration: 6500.
# iteration: 7000.
# iteration: 7500.
# iteration: 8000.
# iteration: 8500.
# iteration: 9000.
# iteration: 9500.
# p1: 5738, p2: 4229, d: 33
# save model as: self_20191211_230735
# time: 44.11207890510559s

# %%
train(name='self', rounds=20_000)
# Out:
# iteration: 0.
# iteration: 1000.
# iteration: 2000.
# iteration: 3000.
# iteration: 4000.
# iteration: 5000.
# iteration: 6000.
# iteration: 7000.
# iteration: 8000.
# iteration: 9000.
# iteration: 10000.
# iteration: 11000.
# iteration: 12000.
# iteration: 13000.
# iteration: 14000.
# iteration: 15000.
# iteration: 16000.
# iteration: 17000.
# iteration: 18000.
# iteration: 19000.
# p1: 11699, p2: 8255, d: 46
# save model as: self_20191211_230903
# time: 87.62328958511353s
