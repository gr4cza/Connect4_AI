# %%
from agent.q_learn import QLearnTrain, QLearn
from board import PLAYER1, PLAYER2
from agent.random_agent import RandomAgent
from agent.min_max import MinMaxAgentWAlphaBeta
from evaluator import AdvancedScore
from agent_game import play_n_game

# %%
train = QLearnTrain(PLAYER2)
train.learn(10_000, against=RandomAgent(), name=f'random_10M')
# Out:
# iteration: 0.
# iteration: 1000.
# iteration: 2000.
# iteration: 3000.
# iteration: 4000.
# iteration: 5000.
# iteration: 6000.
# iteration: 7000.
# iteration: 8000.
# iteration: 9000.
# p1: 4877, p2: 5098, d: 25
# save model as: random_10M_20191112_182320
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-4c3d3ef6adff> in <module>
#       1 train = QLearnTrain(PLAYER2)
# ----> 2 train.learn(10_000, against=RandomAgent(), name=f'random_10M')
#
# ~/Connect4_AI/connect4/agent/q_learn.py in learn(self, iterations, against, name)
#     118
#     119         print(f'p1: {p1}, p2: {p2}, d: {d}')
# --> 120         self._save_learn_dict(name)
#     121         if self_play:
#     122             against._save_learn_dict(name + '_p2')
#
# ~/Connect4_AI/connect4/agent/q_learn.py in _save_learn_dict(self, name)
# ...

# %%
train.reset()
train.learn(1_000_000, name='self_1M')
# Out:
# iteration: 0.
# iteration: 100000.
# iteration: 200000.
# iteration: 300000.
# iteration: 400000.
# iteration: 500000.
# iteration: 600000.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-87621723427f> in <module>
#       1 train.reset()
# ----> 2 train.learn(1_000_000, name='self_1M')
#
# ~/Connect4_AI/connect4/agent/q_learn.py in learn(self, iterations, against, name)
#      97                     current_player = PLAYER2
#      98                 else:
# ---> 99                     column = against.move(board)
#     100                     current_player = PLAYER1
#     101                 board.add_token(column)
#
# ~/Connect4_AI/connect4/agent/q_learn.py in move(self, board)
#      55
#      56     def move(self, board):
# ---> 57         b_hash = board.get_hash()
#      58         if random.uniform(0, 1) <= self.exploration_rate:
# ...

# %%
train.reset()

# %%
adv_score = AdvancedScore()
train = QLearn(PLAYER1, source_name='/content/drive/My Drive/Connect4_AI/connect4/models/self_1M_20191110_163913.pkl')

play_n_game(1000, train, RandomAgent())
play_n_game(1, train, MinMaxAgentWAlphaBeta(5, adv_score.score, PLAYER2))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-306def06d90d> in <module>
#       1 adv_score = AdvancedScore()
# ----> 2 train = QLearn(PLAYER1, source_name='/content/drive/My Drive/Connect4_AI/connect4/models/self_1M_20191110_163913.pkl')
#       3
#       4 play_n_game(1000, train, RandomAgent())
#       5 play_n_game(1, train, MinMaxAgentWAlphaBeta(5, adv_score.score, PLAYER2))
#
# D:\BME_Code\Szak_Doga\Connect4_AI\connect4\agent\q_learn.py in __init__(self, player, source_name)
#      12     def __init__(self, player, source_name=None):
#      13         self.player = player
# ---> 14         self._states_value = self._load_learn_dict(source_name)
#      15
#      16     def move(self, board):
#
# D:\BME_Code\Szak_Doga\Connect4_AI\connect4\agent\q_learn.py in _load_learn_dict(source_name)
#      27     def _load_learn_dict(source_name):
# ...

# %%
train = QLearn(PLAYER1, source_name='/content/drive/My Drive/Connect4_AI/connect4/models/random_10M_20191110_154518.pkl')

play_n_game(1000, train, RandomAgent())
play_n_game(1, train, MinMaxAgentWAlphaBeta(5, adv_score.score, PLAYER2))
# Out:
# 0
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  , O,  ,  ,  ]
# [ ,  ,  , O,  ,  ,  ]
# [ ,  ,  , O, X,  ,  ]
# [X, O,  , O, X, X,  ]
#
# 1
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  , X, X,  ,  ]
# [O, O, O, O, X,  ,  ]
#
# 2
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  , X,  ,  ,  ]
# [ , X, O, O, O, O, X]
#
# 3
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  , X,  ,  ,  ]
# [ ,  ,  , X,  ,  ,  ]
# [ , O, O, O, O,  , X]
#
# 4
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  , X,  ]
# [X, O, O, O, O, X,  ]
#
# 5
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  , X,  ,  ]
# [ , X, O, O, O, O, X]
#
# 6
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# [ ,  ,  ,  ,  ,  ,  ]
# ...

# %%
train = None
