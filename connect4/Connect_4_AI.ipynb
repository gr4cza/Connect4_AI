# %%
from google.colab import drive
import sys
drive.mount('/content/drive')
# %cd '/content/drive/My Drive/Connect4_AI/connect4'
sys.path.append('/content/drive/My Drive/Connect4_AI/connect4')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive/Connect4_AI/connect4

# %%
from agent.q_learn import QLearnTrain, QLearn
from board import PLAYER1, PLAYER2
from agent.random_agent import RandomAgent
from agent.min_max import MinMaxAgentWAlphaBeta
from evaluator import AdvancedScore
from agent_game import play_n_game

# %%
adv_score = AdvancedScore()

# %%
train = QLearnTrain(PLAYER1)

# %%
train.learn(10_000_000, against=RandomAgent(), name=f'random_10M_p1')
train.player = PLAYER2
train.learn(10_000_000, against=RandomAgent(), name=f'random_10M_both')
train.reset()
# Out:
# iteration: 0.
# iteration: 500000.
# iteration: 1000000.
# iteration: 1500000.
# iteration: 2000000.
# iteration: 2500000.
# iteration: 3000000.
# iteration: 3500000.
# iteration: 4000000.
# iteration: 4500000.
# iteration: 5000000.
# iteration: 5500000.
# iteration: 6000000.
# iteration: 6500000.
# iteration: 7000000.
# iteration: 7500000.
# iteration: 8000000.
# iteration: 8500000.
# iteration: 9000000.
# iteration: 9500000.
# p1: 8774613, p2: 1217224, d: 8163
# save model as: random_10M_p1_20191111_015508
# iteration: 0.
# iteration: 500000.
# iteration: 1000000.
# iteration: 1500000.
# iteration: 2000000.
# iteration: 2500000.
# iteration: 3000000.
# iteration: 3500000.
# iteration: 4000000.
# iteration: 4500000.
# iteration: 5000000.
# iteration: 5500000.
# iteration: 6000000.
# iteration: 6500000.
# iteration: 7000000.
# iteration: 7500000.
# iteration: 8000000.
# iteration: 8500000.
# iteration: 9000000.
# iteration: 9500000.
# p1: 2110386, p2: 7876472, d: 13142
# ...

# %%
train.player = PLAYER1
train.learn(1_000_000, name=f'self_1M')
train.reset()
# Out:
# iteration: 0.
# iteration: 50000.
# iteration: 100000.
# iteration: 150000.
# iteration: 200000.
# iteration: 250000.
# iteration: 300000.
# iteration: 350000.
# iteration: 400000.
# iteration: 450000.
# iteration: 500000.
# iteration: 550000.
# iteration: 600000.
# iteration: 650000.
# iteration: 700000.
# iteration: 750000.
# iteration: 800000.
# iteration: 850000.
# iteration: 900000.
# iteration: 950000.
# p1: 582861, p2: 414136, d: 3003
# save model as: self_1M_p1_20191111_054422
# save model as: self_1M_p2_20191111_054437

# %%
train.player = PLAYER1
train.learn(1_000, against=MinMaxAgentWAlphaBeta(6, adv_score.score, PLAYER2), name=f'min_max_6_1K_p1')
train.player = PLAYER2
train.learn(1_000, against=MinMaxAgentWAlphaBeta(6, adv_score.score, PLAYER1), name=f'min_max_6_1K_both')
train.reset()
# Out:
# iteration: 0.
# iteration: 50.
# iteration: 100.
# iteration: 150.
# iteration: 200.
# iteration: 250.
# iteration: 300.
# iteration: 350.
# iteration: 400.
# iteration: 450.
# iteration: 500.
# iteration: 550.
# iteration: 600.
# iteration: 650.
# iteration: 700.
# iteration: 750.
# iteration: 800.
# iteration: 850.
# iteration: 900.
# iteration: 950.
# p1: 6, p2: 994, d: 0
# save model as: min_max_6_1K_p1_20191111_084903
# iteration: 0.
# iteration: 50.
# iteration: 100.
# iteration: 150.
# iteration: 200.
# iteration: 250.
# iteration: 300.
# iteration: 350.
# iteration: 400.
# iteration: 450.
# iteration: 500.
# iteration: 550.
# iteration: 600.
# iteration: 650.
# iteration: 700.
# iteration: 750.
# iteration: 800.
# iteration: 850.
# iteration: 900.
# iteration: 950.
# p1: 1000, p2: 0, d: 0
# save model as: min_max_6_1K_both_20191111_100810

# %%
train.player = PLAYER1
train.learn(10_000, against=MinMaxAgentWAlphaBeta(5, adv_score.score, PLAYER2), name=f'min_max_5_10K_p1')
train.player = PLAYER2
train.learn(10_000, against=MinMaxAgentWAlphaBeta(5, adv_score.score, PLAYER1), name=f'min_max_5_10K_both')
train.reset()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-63a635e68675> in <module>()
# ----> 1 train.player = PLAYER1
#       2 train.learn(10_000, against=MinMaxAgentWAlphaBeta(5, adv_score.score, PLAYER2), name=f'min_max_5_10K_p1')
#       3 train.player = PLAYER2
#       4 train.learn(10_000, against=MinMaxAgentWAlphaBeta(5, adv_score.score, PLAYER1), name=f'min_max_5_10K_both')
#       5 train.reset()
#
# NameError: name 'PLAYER1' is not defined

# %%
train.player = PLAYER1
train.learn(100_000, against=MinMaxAgentWAlphaBeta(4, adv_score.score, PLAYER2), name=f'min_max_4_100K_p1')
train.player = PLAYER2
train.learn(100_000, against=MinMaxAgentWAlphaBeta(4, adv_score.score, PLAYER1), name=f'min_max_4_100K_both')
train.reset()
# Out:
# iteration: 0.
# iteration: 5000.
# iteration: 10000.
# iteration: 15000.
# iteration: 20000.
# iteration: 25000.
# iteration: 30000.
# iteration: 35000.
# iteration: 40000.
# iteration: 45000.
# iteration: 50000.
# iteration: 55000.
# iteration: 60000.
# iteration: 65000.
# iteration: 70000.
# iteration: 75000.
